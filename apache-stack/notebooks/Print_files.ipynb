# %%
from pyspark.sql import SparkSession
spark = (
    SparkSession.builder
    .appName("print-files")
    .master("spark://spark-master:7077")
    .config("spark.cores.max", "1")
    .config("spark.executor.cores", "1")
    .getOrCreate()
)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/23 18:46:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df2 = spark.read.parquet("hdfs://namenode:8020/nifi/crypto-prices/crypto-quotes-20251106-214622.parquet")
df2.show(5)
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +-------------+--------+---------+---------+--------------+----------+---------------+
# |current_price|    high|      low|     open|previous_close| timestamp|         symbol|
# +-------------+--------+---------+---------+--------------+----------+---------------+
# |        156.1|  163.06|    153.8|   161.22|        161.22|1762465073|BINANCE:SOLUSDT|
# |    100937.93|104200.0|100300.95|103619.65|     103619.64|1762465073|BINANCE:BTCUSDT|
# |      3321.82| 3456.46|  3245.45|  3434.34|       3434.34|1762465073|BINANCE:ETHUSDT|
# |    100922.79|104200.0|100300.95|103606.18|     103606.17|1762465092|BINANCE:BTCUSDT|
# |       156.02|  163.06|    153.8|   161.12|        161.12|1762465092|BINANCE:SOLUSDT|
# +-------------+--------+---------+---------+--------------+----------+---------------+
# only showing top 5 rows

# %%
df3 = spark.read.parquet("hdfs://namenode:8020/nifi/stock-prices/stock_prices_2025-11-15-11.parquet")

# for i, row in enumerate(df3.take(7)):
#     print(f"Row: {i}")
#     for col, val in row.asDict().items():
#         print(f"{col:30s} {val}")
#     print(f"{'-'*50}")
df3.show(vertical=True)
# Out:
# [Stage 6:>                                                          (0 + 1) / 1]
# -RECORD 0-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 6774.31005859375
#  dayLow                     | 6646.8701171875
#  exchange                   | SNP
#  fiftyDayAverage            | 6704.16798828125
#  lastPrice                  | 6734.10986328125
#  lastVolume                 | 5042660000
#  marketCap                  | null
#  open                       | 6672.14013671875
#  previousClose              | 6737.49
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 6737.490234375
#  shares                     | null
#  tenDayAverageVolume        | 5588233000
#  threeMonthAverageVolume    | 5351588153
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 6148.468586425781
#  yearChange                 | 0.14261009861199553
#  yearHigh                   | 6920.33984375
#  yearLow                    | 4835.0400390625
#  ticker                     | ^GSPC
#  fetch_timestamp            | 2025-11-15 11:40:35
# -RECORD 1-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 47380.0703125
#  dayLow                     | 46863.05078125
#  exchange                   | DJI
#  fiftyDayAverage            | 46611.83703125
#  lastPrice                  | 47147.48046875
#  lastVolume                 | 552330000
#  marketCap                  | null
#  open                       | 47222.37890625
#  previousClose              | 47457.22
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 47457.21875
#  shares                     | null
#  tenDayAverageVolume        | 530167000
#  threeMonthAverageVolume    | 503966461
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 43856.52126953125
#  yearChange                 | 0.08660782240272502
#  yearHigh                   | 48431.5703125
#  yearLow                    | 36611.78125
#  ticker                     | ^DJI
#  fetch_timestamp            | 2025-11-15 11:40:36
# -RECORD 2-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 23073.1796875
#  dayLow                     | 22436.7890625
#  exchange                   | NIM
#  fiftyDayAverage            | 22835.22734375
#  lastPrice                  | 22900.58984375
#  lastVolume                 | 10841540000
#  marketCap                  | null
#  open                       | 22544.720703125
#  previousClose              | 22870.355
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 22870.359375
#  shares                     | null
#  tenDayAverageVolume        | 9953880000
#  threeMonthAverageVolume    | 9628213846
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 20174.438125
#  yearChange                 | 0.2186473350519316
#  yearHigh                   | 24019.990234375
#  yearLow                    | 14784.0302734375
#  ticker                     | ^IXIC
#  fetch_timestamp            | 2025-11-15 11:40:37
# -RECORD 3-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 6774.31005859375
#  dayLow                     | 6646.8701171875
#  exchange                   | SNP
#  fiftyDayAverage            | 6704.16798828125
#  lastPrice                  | 6734.10986328125
#  lastVolume                 | 5042660000
#  marketCap                  | null
#  open                       | 6672.14013671875
#  previousClose              | 6737.49
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 6737.490234375
#  shares                     | null
#  tenDayAverageVolume        | 5588233000
#  threeMonthAverageVolume    | 5351588153
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 6148.468586425781
#  yearChange                 | 0.14261009861199553
#  yearHigh                   | 6920.33984375
#  yearLow                    | 4835.0400390625
#  ticker                     | ^GSPC
#  fetch_timestamp            | 2025-11-15 11:41:34
# -RECORD 4-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 47380.0703125
#  dayLow                     | 46863.05078125
#  exchange                   | DJI
#  fiftyDayAverage            | 46611.83703125
#  lastPrice                  | 47147.48046875
#  lastVolume                 | 552330000
#  marketCap                  | null
#  open                       | 47222.37890625
#  previousClose              | 47457.22
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 47457.21875
#  shares                     | null
#  tenDayAverageVolume        | 530167000
#  threeMonthAverageVolume    | 503966461
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 43856.52126953125
#  yearChange                 | 0.08660782240272502
#  yearHigh                   | 48431.5703125
#  yearLow                    | 36611.78125
#  ticker                     | ^DJI
#  fetch_timestamp            | 2025-11-15 11:41:35
# -RECORD 5-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 23073.1796875
#  dayLow                     | 22436.7890625
#  exchange                   | NIM
#  fiftyDayAverage            | 22835.22734375
#  lastPrice                  | 22900.58984375
#  lastVolume                 | 10841540000
#  marketCap                  | null
#  open                       | 22544.720703125
#  previousClose              | 22870.355
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 22870.359375
#  shares                     | null
#  tenDayAverageVolume        | 9953880000
#  threeMonthAverageVolume    | 9628213846
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 20174.438125
#  yearChange                 | 0.2186473350519316
#  yearHigh                   | 24019.990234375
#  yearLow                    | 14784.0302734375
#  ticker                     | ^IXIC
#  fetch_timestamp            | 2025-11-15 11:41:36
# -RECORD 6-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 6774.31005859375
#  dayLow                     | 6646.8701171875
#  exchange                   | SNP
#  fiftyDayAverage            | 6704.16798828125
#  lastPrice                  | 6734.10986328125
#  lastVolume                 | 5042660000
#  marketCap                  | null
#  open                       | 6672.14013671875
#  previousClose              | 6737.49
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 6737.490234375
#  shares                     | null
#  tenDayAverageVolume        | 5588233000
#  threeMonthAverageVolume    | 5351588153
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 6148.468586425781
#  yearChange                 | 0.14261009861199553
#  yearHigh                   | 6920.33984375
#  yearLow                    | 4835.0400390625
#  ticker                     | ^GSPC
#  fetch_timestamp            | 2025-11-15 11:42:34
# -RECORD 7-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 47380.0703125
#  dayLow                     | 46863.05078125
#  exchange                   | DJI
#  fiftyDayAverage            | 46611.83703125
#  lastPrice                  | 47147.48046875
#  lastVolume                 | 552330000
#  marketCap                  | null
#  open                       | 47222.37890625
#  previousClose              | 47457.22
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 47457.21875
#  shares                     | null
#  tenDayAverageVolume        | 530167000
#  threeMonthAverageVolume    | 503966461
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 43856.52126953125
#  yearChange                 | 0.08660782240272502
#  yearHigh                   | 48431.5703125
#  yearLow                    | 36611.78125
#  ticker                     | ^DJI
#  fetch_timestamp            | 2025-11-15 11:42:35
# -RECORD 8-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 23073.1796875
#  dayLow                     | 22436.7890625
#  exchange                   | NIM
#  fiftyDayAverage            | 22835.22734375
#  lastPrice                  | 22900.58984375
#  lastVolume                 | 10841540000
#  marketCap                  | null
#  open                       | 22544.720703125
#  previousClose              | 22870.355
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 22870.359375
#  shares                     | null
#  tenDayAverageVolume        | 9953880000
#  threeMonthAverageVolume    | 9628213846
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 20174.438125
#  yearChange                 | 0.2186473350519316
#  yearHigh                   | 24019.990234375
#  yearLow                    | 14784.0302734375
#  ticker                     | ^IXIC
#  fetch_timestamp            | 2025-11-15 11:42:36
# -RECORD 9-----------------------------------------
#  currency                   | USD
#  dayHigh                    | 6774.31005859375
#  dayLow                     | 6646.8701171875
#  exchange                   | SNP
#  fiftyDayAverage            | 6704.16798828125
#  lastPrice                  | 6734.10986328125
#  lastVolume                 | 5042660000
#  marketCap                  | null
#  open                       | 6672.14013671875
#  previousClose              | 6737.49
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 6737.490234375
#  shares                     | null
#  tenDayAverageVolume        | 5588233000
#  threeMonthAverageVolume    | 5351588153
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 6148.468586425781
#  yearChange                 | 0.14261009861199553
#  yearHigh                   | 6920.33984375
#  yearLow                    | 4835.0400390625
#  ticker                     | ^GSPC
#  fetch_timestamp            | 2025-11-15 11:43:34
# -RECORD 10----------------------------------------
#  currency                   | USD
#  dayHigh                    | 47380.0703125
#  dayLow                     | 46863.05078125
#  exchange                   | DJI
#  fiftyDayAverage            | 46611.83703125
#  lastPrice                  | 47147.48046875
#  lastVolume                 | 552330000
#  marketCap                  | null
#  open                       | 47222.37890625
#  previousClose              | 47457.22
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 47457.21875
#  shares                     | null
#  tenDayAverageVolume        | 530167000
#  threeMonthAverageVolume    | 503966461
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 43856.52126953125
#  yearChange                 | 0.08660782240272502
#  yearHigh                   | 48431.5703125
#  yearLow                    | 36611.78125
#  ticker                     | ^DJI
#  fetch_timestamp            | 2025-11-15 11:43:35
# -RECORD 11----------------------------------------
#  currency                   | USD
#  dayHigh                    | 23073.1796875
#  dayLow                     | 22436.7890625
#  exchange                   | NIM
#  fiftyDayAverage            | 22835.22734375
#  lastPrice                  | 22900.58984375
#  lastVolume                 | 10841540000
#  marketCap                  | null
#  open                       | 22544.720703125
#  previousClose              | 22870.355
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 22870.359375
#  shares                     | null
#  tenDayAverageVolume        | 9953880000
#  threeMonthAverageVolume    | 9628213846
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 20174.438125
#  yearChange                 | 0.2186473350519316
#  yearHigh                   | 24019.990234375
#  yearLow                    | 14784.0302734375
#  ticker                     | ^IXIC
#  fetch_timestamp            | 2025-11-15 11:43:36
# -RECORD 12----------------------------------------
#  currency                   | USD
#  dayHigh                    | 6774.31005859375
#  dayLow                     | 6646.8701171875
#  exchange                   | SNP
#  fiftyDayAverage            | 6704.16798828125
#  lastPrice                  | 6734.10986328125
#  lastVolume                 | 5042660000
#  marketCap                  | null
#  open                       | 6672.14013671875
#  previousClose              | 6737.49
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 6737.490234375
#  shares                     | null
#  tenDayAverageVolume        | 5588233000
#  threeMonthAverageVolume    | 5351588153
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 6148.468586425781
#  yearChange                 | 0.14261009861199553
#  yearHigh                   | 6920.33984375
#  yearLow                    | 4835.0400390625
#  ticker                     | ^GSPC
#  fetch_timestamp            | 2025-11-15 11:44:34
# -RECORD 13----------------------------------------
#  currency                   | USD
#  dayHigh                    | 47380.0703125
#  dayLow                     | 46863.05078125
#  exchange                   | DJI
#  fiftyDayAverage            | 46611.83703125
#  lastPrice                  | 47147.48046875
#  lastVolume                 | 552330000
#  marketCap                  | null
#  open                       | 47222.37890625
#  previousClose              | 47457.22
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 47457.21875
#  shares                     | null
#  tenDayAverageVolume        | 530167000
#  threeMonthAverageVolume    | 503966461
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 43856.52126953125
#  yearChange                 | 0.08660782240272502
#  yearHigh                   | 48431.5703125
#  yearLow                    | 36611.78125
#  ticker                     | ^DJI
#  fetch_timestamp            | 2025-11-15 11:44:35
# -RECORD 14----------------------------------------
#  currency                   | USD
#  dayHigh                    | 23073.1796875
#  dayLow                     | 22436.7890625
#  exchange                   | NIM
#  fiftyDayAverage            | 22835.22734375
#  lastPrice                  | 22900.58984375
#  lastVolume                 | 10841540000
#  marketCap                  | null
#  open                       | 22544.720703125
#  previousClose              | 22870.355
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 22870.359375
#  shares                     | null
#  tenDayAverageVolume        | 9953880000
#  threeMonthAverageVolume    | 9628213846
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 20174.438125
#  yearChange                 | 0.2186473350519316
#  yearHigh                   | 24019.990234375
#  yearLow                    | 14784.0302734375
#  ticker                     | ^IXIC
#  fetch_timestamp            | 2025-11-15 11:44:36
# -RECORD 15----------------------------------------
#  currency                   | USD
#  dayHigh                    | 6774.31005859375
#  dayLow                     | 6646.8701171875
#  exchange                   | SNP
#  fiftyDayAverage            | 6704.16798828125
#  lastPrice                  | 6734.10986328125
#  lastVolume                 | 5042660000
#  marketCap                  | null
#  open                       | 6672.14013671875
#  previousClose              | 6737.49
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 6737.490234375
#  shares                     | null
#  tenDayAverageVolume        | 5588233000
#  threeMonthAverageVolume    | 5351588153
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 6148.468586425781
#  yearChange                 | 0.14261009861199553
#  yearHigh                   | 6920.33984375
#  yearLow                    | 4835.0400390625
#  ticker                     | ^GSPC
#  fetch_timestamp            | 2025-11-15 11:45:34
# -RECORD 16----------------------------------------
#  currency                   | USD
#  dayHigh                    | 47380.0703125
#  dayLow                     | 46863.05078125
#  exchange                   | DJI
#  fiftyDayAverage            | 46611.83703125
#  lastPrice                  | 47147.48046875
#  lastVolume                 | 552330000
#  marketCap                  | null
#  open                       | 47222.37890625
#  previousClose              | 47457.22
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 47457.21875
#  shares                     | null
#  tenDayAverageVolume        | 530167000
#  threeMonthAverageVolume    | 503966461
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 43856.52126953125
#  yearChange                 | 0.08660782240272502
#  yearHigh                   | 48431.5703125
#  yearLow                    | 36611.78125
#  ticker                     | ^DJI
#  fetch_timestamp            | 2025-11-15 11:45:35
# -RECORD 17----------------------------------------
#  currency                   | USD
#  dayHigh                    | 23073.1796875
#  dayLow                     | 22436.7890625
#  exchange                   | NIM
#  fiftyDayAverage            | 22835.22734375
#  lastPrice                  | 22900.58984375
#  lastVolume                 | 10841540000
#  marketCap                  | null
#  open                       | 22544.720703125
#  previousClose              | 22870.355
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 22870.359375
#  shares                     | null
#  tenDayAverageVolume        | 9953880000
#  threeMonthAverageVolume    | 9628213846
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 20174.438125
#  yearChange                 | 0.2186473350519316
#  yearHigh                   | 24019.990234375
#  yearLow                    | 14784.0302734375
#  ticker                     | ^IXIC
#  fetch_timestamp            | 2025-11-15 11:45:36
# -RECORD 18----------------------------------------
#  currency                   | USD
#  dayHigh                    | 6774.31005859375
#  dayLow                     | 6646.8701171875
#  exchange                   | SNP
#  fiftyDayAverage            | 6704.16798828125
#  lastPrice                  | 6734.10986328125
#  lastVolume                 | 5042660000
#  marketCap                  | null
#  open                       | 6672.14013671875
#  previousClose              | 6737.49
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 6737.490234375
#  shares                     | null
#  tenDayAverageVolume        | 5588233000
#  threeMonthAverageVolume    | 5351588153
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 6148.468586425781
#  yearChange                 | 0.14261009861199553
#  yearHigh                   | 6920.33984375
#  yearLow                    | 4835.0400390625
#  ticker                     | ^GSPC
#  fetch_timestamp            | 2025-11-15 11:46:34
# -RECORD 19----------------------------------------
#  currency                   | USD
#  dayHigh                    | 47380.0703125
#  dayLow                     | 46863.05078125
#  exchange                   | DJI
#  fiftyDayAverage            | 46611.83703125
#  lastPrice                  | 47147.48046875
#  lastVolume                 | 552330000
#  marketCap                  | null
#  open                       | 47222.37890625
#  previousClose              | 47457.22
#  quoteType                  | INDEX
#  regularMarketPreviousClose | 47457.21875
#  shares                     | null
#  tenDayAverageVolume        | 530167000
#  threeMonthAverageVolume    | 503966461
#  timezone                   | America/New_York
#  twoHundredDayAverage       | 43856.52126953125
#  yearChange                 | 0.08660782240272502
#  yearHigh                   | 48431.5703125
#  yearLow                    | 36611.78125
#  ticker                     | ^DJI
#  fetch_timestamp            | 2025-11-15 11:46:35
# only showing top 20 rows

# %%
df4 = spark.read.parquet("hdfs://namenode:8020/nifi/forex/forex_2025-11-15_14-45-01.parquet")
for i, row in enumerate(df4.take(20)):
    print(f"Row: {i}")
    for col, val in row.asDict().items():
        print(f"{col:30s} {val}")
    print(f"{'-'*50}")
# df4.show(vertical=True)
# Out:
# Row: 0
# ticker                         C:USDAED
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=4, vw=3.6729, o=3.6728, c=3.6729, h=3.6729, l=3.6728, t=1763078400000, n=4)]
# status                         OK
# request_id                     b46e06348f9cf631ea12bd789e3bcd9b
# count                          1
# --------------------------------------------------
# Row: 1
# ticker                         C:USDARS
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=9418, vw=1406.5591, o=1408.0072, c=1403.6762, h=1409.5133, l=1401.8503, t=1763078400000, n=9418)]
# status                         OK
# request_id                     49825d73e5a3c9a0b9ee51bdec056aba
# count                          1
# --------------------------------------------------
# Row: 2
# ticker                         C:USDALL
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=2, vw=81.9133, o=81.0266820347847, c=82.8, h=82.8, l=81.0266820347847, t=1763078400000, n=2)]
# status                         OK
# request_id                     b661ab009c4601cb499d888c5d8eb14c
# count                          1
# --------------------------------------------------
# Row: 3
# ticker                         C:USDAUD
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=189637, vw=1.5314, o=1.528677999266235, c=1.5291, h=1.537539015052507, l=1.525785779676534, t=1763078400000, n=189637)]
# status                         OK
# request_id                     0bbe7c0d3a6e787c3bf1bd71643b8832
# count                          1
# --------------------------------------------------
# Row: 4
# ticker                         C:USDBBD
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=1, vw=1.97, o=1.970014966711968, c=1.970014966711968, h=1.970014966711968, l=1.970014966711968, t=1763078400000, n=1)]
# status                         OK
# request_id                     7985203f700e8a83089327f18e6871f1
# count                          1
# --------------------------------------------------
# Row: 5
# ticker                         C:USDBAM
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=1, vw=1.6737, o=1.673691272858642, c=1.673691272858642, h=1.673691272858642, l=1.673691272858642, t=1763078400000, n=1)]
# status                         OK
# request_id                     e4068b4f4aedfd39c004347d8d8edfac
# count                          1
# --------------------------------------------------
# Row: 6
# ticker                         C:USDBDT
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=1, vw=120.5853, o=120.5852500473086, c=120.5852500473086, h=120.5852500473086, l=120.5852500473086, t=1763078400000, n=1)]
# status                         OK
# request_id                     76c69dca26c956c51a5a1a6917b0879e
# count                          1
# --------------------------------------------------
# Row: 7
# ticker                         C:USDAWG
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=2, vw=1.7925, o=1.7925, c=1.7925, h=1.7925, l=1.7925, t=1763078400000, n=2)]
# status                         OK
# request_id                     a63f057aef884d9e8e5f6c97014ad00b
# count                          1
# --------------------------------------------------
# Row: 8
# ticker                         C:USDBHD
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=44, vw=0.3746, o=0.37443362078601, c=0.374403565912152, h=0.37698, l=0.374389068630825, t=1763078400000, n=44)]
# status                         OK
# request_id                     a866320052d18ed853188b3482308d9f
# count                          1
# --------------------------------------------------
# Row: 9
# ticker                         C:USDBGN
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=107, vw=1.6718, o=1.672, c=1.673, h=1.67451, l=1.6688, t=1763078400000, n=107)]
# status                         OK
# request_id                     a31556e469bffde1e42ad0b0f92625ec
# count                          1
# --------------------------------------------------
# Row: 10
# ticker                         C:USDBND
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=2, vw=1.2782, o=1.276663414550284, c=1.279825904453887, h=1.279825904453887, l=1.276663414550284, t=1763078400000, n=2)]
# status                         OK
# request_id                     a55b3824383279335934d54ea8d601b3
# count                          1
# --------------------------------------------------
# Row: 11
# ticker                         C:USDBIF
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=4, vw=2922.048, o=2920.37185873494, c=2921.0, h=2925.82015861274, l=2920.37185873494, t=1763078400000, n=4)]
# status                         OK
# request_id                     699542e323043e78fff231046557b4c9
# count                          1
# --------------------------------------------------
# Row: 12
# ticker                         C:USDBOB
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=1, vw=6.7342, o=6.73416022983365, c=6.73416022983365, h=6.73416022983365, l=6.73416022983365, t=1763078400000, n=1)]
# status                         OK
# request_id                     c789732adf103d73d0885164374d578e
# count                          1
# --------------------------------------------------
# Row: 13
# ticker                         C:USDBRL
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=5361, vw=5.2933, o=5.2964, c=5.2959, h=5.3169, l=5.26646398680013, t=1763078400000, n=5361)]
# status                         OK
# request_id                     9d0853e90d6773e9f08eb06adf0eac9a
# count                          1
# --------------------------------------------------
# Row: 14
# ticker                         C:USDBWP
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=1, vw=14.0911, o=14.09107330248241, c=14.09107330248241, h=14.09107330248241, l=14.09107330248241, t=1763078400000, n=1)]
# status                         OK
# request_id                     b0503a0a921233541150c5074c5456f4
# count                          1
# --------------------------------------------------
# Row: 15
# ticker                         C:USDBSD
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=1, vw=0.9934, o=0.993394002993343, c=0.993394002993343, h=0.993394002993343, l=0.993394002993343, t=1763078400000, n=1)]
# status                         OK
# request_id                     929665dd965b1d48c24e6c6ce6c64e74
# count                          1
# --------------------------------------------------
# Row: 16
# ticker                         C:USDBZD
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=1, vw=1.9671, o=1.967090436787146, c=1.967090436787146, h=1.967090436787146, l=1.967090436787146, t=1763078400000, n=1)]
# status                         OK
# request_id                     b59e9c548364897606fc975e5c389ae5
# count                          1
# --------------------------------------------------
# Row: 17
# ticker                         C:USDCHF
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=198559, vw=0.7918, o=0.79325, c=0.7938, h=0.7948, l=0.7875, t=1763078400000, n=198559)]
# status                         OK
# request_id                     f936690a72a07079576e3bcfbb3eca68
# count                          1
# --------------------------------------------------
# Row: 18
# ticker                         C:USDCDF
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=1, vw=2173.0, o=2173.0, c=2173.0, h=2173.0, l=2173.0, t=1763078400000, n=1)]
# status                         OK
# request_id                     fdef0bb88e6b073b6f155ea165c7297a
# count                          1
# --------------------------------------------------
# Row: 19
# ticker                         C:USDCAD
# queryCount                     1
# resultsCount                   1
# adjusted                       True
# results                        [Row(v=152230, vw=1.4029, o=1.40364, c=1.4021, h=1.40452, l=1.4012, t=1763078400000, n=152230)]
# status                         OK
# request_id                     80f96b9b972de28880ab60933fffcc6f
# count                          1
# --------------------------------------------------

# %%
spark.stop()
