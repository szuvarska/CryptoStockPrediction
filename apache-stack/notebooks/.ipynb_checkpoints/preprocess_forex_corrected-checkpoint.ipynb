# %%
from pyspark.sql import SparkSession
import pyspark
print(pyspark.__version__)
from pyspark.sql import SparkSession
from pyspark.sql.utils import AnalysisException
from pyspark.sql import functions as F
# Out:
# 3.4.1

# %%
spark = (
    SparkSession.builder 
    .appName("preprocess_forex") 
    .master("spark://spark-master:7077") 
    .config("spark.sql.warehouse.dir", "hdfs://namenode:8020/user/nifi/forex") 
    .config("spark.cores.max", "1")
    .config("spark.executor.cores", "1")
    .getOrCreate()
    )
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/24 03:39:01 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/24 03:39:02 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
df2 = spark.read.parquet("hdfs://namenode:8020/nifi/forex/forex_2025-11-22_03-30-01.parquet")
df2.show(3, vertical=True, truncate=False)
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# -RECORD 0--------------------------------------------------------------------------------------------------------
#  ticker       | C:USDAED
#  queryCount   | 1
#  resultsCount | 1
#  adjusted     | true
#  results      | [{4, 3.6729, 3.6728, 3.6729, 3.6729, 3.6728, 1763683200000, 4}]
#  status       | OK
#  request_id   | 03115734e56e15ff780591f3892f9336
#  count        | 1
# -RECORD 1--------------------------------------------------------------------------------------------------------
#  ticker       | C:USDAUD
#  queryCount   | 1
#  resultsCount | 1
#  adjusted     | true
#  results      | [{258746, 1.5515, 1.55051, 1.5487, 1.557268550961613, 1.547269070091289, 1763683200000, 258746}]
#  status       | OK
#  request_id   | 5bd8461acbd8119bd0bd3a8ba14e44c9
#  count        | 1
# -RECORD 2--------------------------------------------------------------------------------------------------------
# ...

# %%
def unpack_results(df,results_col='results', ticker_col='ticker'):
    """
    Rozpakowuje zagnieżdżoną kolumnę wyników (np. z API rynkowych) do płaskiej struktury tabelarycznej.

    Funkcja:
    - pobiera pierwszy element listy w kolumnie `results`
    - wyciąga pola OHLCV (open, high, low, close, volume, adjusted_close)
    - konwertuje znacznik czasu w milisekundach na typ `timestamp`
    - usuwa dane wejściowe i kolumny pomocnicze

    Parametry:
        df (DataFrame): wejściowy Spark DataFrame zawierający kolumnę z wynikami
        results_col (str): nazwa kolumny zawierającej listę wyników (domyślnie "results")

    Zwraca:
        DataFrame: przetworzony DataFrame z płaskimi kolumnami cenowymi i timestampem
    """
    df = df.withColumn("res", F.col(results_col).getItem(0))
    
    df = df.withColumn("VolumeTraded", F.col("res.v")) \
           .withColumn("OpeningPrice", F.col("res.o")) \
           .withColumn("HighestDailyPrice", F.col("res.h")) \
           .withColumn("LowestDailyPrice", F.col("res.l")) \
           .withColumn("ClosingPrice", F.col("res.c")) \
           .withColumn("AveragedPrice", F.col("res.vw")) \
           .withColumn("timestamp", F.col("res.t")) \
           .withColumn("NumberOfTrades", F.col("res.n"))
    
    df = df.withColumn("ticker_clean", F.regexp_replace(F.col(ticker_col), "^C:", ""))
    df = df.withColumn("CurrencyFrom", F.col("ticker_clean").substr(1,3))
    df = df.withColumn("CurrencyTo", F.expr("substring(ticker_clean, 4, length(ticker_clean))"))
    df = df.withColumn("Date", F.to_date(F.from_unixtime(F.col("timestamp") / 1000)))
    df = df.withColumn("PartitionDate", F.col("Date"))
    res = res.drop('results', 'res', 'ticker_clean', 'ticker', 'queryCount','resultsCount','adjusted','status','request_id','count','timestamp')
    return res

# %%
unpacked = unpack_results(df2)
unpacked.show(3,vertical=True, truncate=False)
# Out:
# -RECORD 0------------------------------
#  VolumeTraded      | 4
#  OpeningPrice      | 3.6728
#  HighestDailyPrice | 3.6729
#  LowestDailyPrice  | 3.6728
#  ClosingPrice      | 3.6729
#  AveragedPrice     | 3.6729
#  NumberOfTrades    | 4
#  CurrencyFrom      | USD
#  CurrencyTo        | AED
#  Date              | 2025-11-21
#  PartitionDate     | 2025-11-21
# -RECORD 1------------------------------
#  VolumeTraded      | 258746
#  OpeningPrice      | 1.55051
#  HighestDailyPrice | 1.557268550961613
#  LowestDailyPrice  | 1.547269070091289
#  ClosingPrice      | 1.5487
#  AveragedPrice     | 1.5515
#  NumberOfTrades    | 258746
#  CurrencyFrom      | USD
#  CurrencyTo        | AUD
#  Date              | 2025-11-21
#  PartitionDate     | 2025-11-21
# -RECORD 2------------------------------
#  VolumeTraded      | 5429
#  OpeningPrice      | 1424.5135
#  HighestDailyPrice | 1424.8414
#  LowestDailyPrice  | 1423.8642
#  ClosingPrice      | 1424.1548
#  AveragedPrice     | 1424.4874
# ...

# %%
currency_splitted = split_ticker(unpacked)
currency_splitted.show(vertical=True, truncate=False)
# Out:
# -RECORD 0------------------------------------------
#  ticker         | C:USDAED
#  queryCount     | 1
#  resultsCount   | 1
#  adjusted       | true
#  status         | OK
#  request_id     | 03115734e56e15ff780591f3892f9336
#  count          | 1
#  interval       | 4
#  open           | 3.6728
#  high           | 3.6729
#  low            | 3.6728
#  close          | 3.6729
#  adjusted_close | 3.6729
#  volume         | 4
#  datetime       | 2025-11-21 00:00:00
#  currency_from  | USD
#  currency_to    | AED
# -RECORD 1------------------------------------------
#  ticker         | C:USDAUD
#  queryCount     | 1
#  resultsCount   | 1
#  adjusted       | true
#  status         | OK
#  request_id     | 5bd8461acbd8119bd0bd3a8ba14e44c9
#  count          | 1
#  interval       | 258746
#  open           | 1.55051
#  high           | 1.557268550961613
#  low            | 1.547269070091289
#  close          | 1.5487
#  adjusted_close | 1.5515
#  volume         | 258746
# ...

# %% [markdown]
# # Preprocessing i zapis do csv

# %%
df = spark8.read.parquet("hdfs://namenode:8020/nifi/forex/")

# %%
df = split_ticker(df)
df = unpack_results(df)

# %%
df.write \
    .option("header", "true") \
    .mode("overwrite") \
    .csv("hdfs://namenode:8020/ready_data/forex")
